# %%
# !rm -rf MLops2025
# !git clone -b mlops-tasks https://github.com/nastyasova/MLops2025.git
# %cd MLops2025

# !pip install -r requirements.txt --quiet || pip install torch torchvision torchaudio datasets scikit-learn pyyaml --quiet
# !pip install transformers==4.41.2 accelerate==0.29.3 peft==0.10.0 --quiet
# Out:
# Cloning into 'MLops2025'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 109 (delta 50), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (109/109), 35.85 KiB | 5.97 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /kaggle/working/MLops2025
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 2.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 4.4 MB/s eta 0:00:000:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.5/511.5 kB 633.1 kB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 61.7 MB/s eta 0:00:00:00:01:01m
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.0 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !ls -R /kaggle/working/MLops2025
# Out:
# /kaggle/working/MLops2025:
# configs  models     requirements.txt  test_data_load.py
# LICENSE  README.md  src		      tests
#
# /kaggle/working/MLops2025/configs:
# train_config.yaml
#
# /kaggle/working/MLops2025/models:
#
# /kaggle/working/MLops2025/src:
# data.py  evaluate.py  __init__.py  model.py  train.py  utils.py
#
# /kaggle/working/MLops2025/tests:
# test_basic.py

# %%
# !python -m src.train
# Out:
# 2025-11-05 21:36:50.679792: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762378610.891972     128 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762378610.951982     128 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# README.md: 7.81kB [00:00, 17.4MB/s]
# plain_text/train-00000-of-00001.parquet: 100%|█| 21.0M/21.0M [00:00<00:00, 44.3M
# plain_text/test-00000-of-00001.parquet: 100%|█| 20.5M/20.5M [00:00<00:00, 34.3MB
# plain_text/unsupervised-00000-of-00001.p(…): 100%|█| 42.0M/42.0M [00:00<00:00, 6
# ...

# %%
# !ls models/distilbert-imdb
# !cat models/distilbert-imdb/metrics.yaml
# Out:
# checkpoint-1563  metrics.yaml	    special_tokens_map.json  tokenizer.json
# config.json	 model.safetensors  tokenizer_config.json    vocab.txt
# epoch: 1.0
# eval_accuracy: 0.90952
# eval_f1: 0.9095152044506115
# eval_loss: 0.22822120785713196
# eval_runtime: 126.9247
# eval_samples_per_second: 196.967
# eval_steps_per_second: 12.314

# %%
# Сохраняем результаты обучения в Kaggle Output
# !mkdir -p /kaggle/working/output_model
# !cp -r models/distilbert-imdb /kaggle/working/output_model/
# !cp configs/train_config.yaml /kaggle/working/output_model/
# !cp -r logs /kaggle/working/output_model/

# Проверим содержимое
# !ls -R /kaggle/working/output_model
# Out:
# cp: cannot stat 'logs': No such file or directory
# /kaggle/working/output_model:
# distilbert-imdb  train_config.yaml
#
# /kaggle/working/output_model/distilbert-imdb:
# checkpoint-1563  metrics.yaml	    special_tokens_map.json  tokenizer.json
# config.json	 model.safetensors  tokenizer_config.json    vocab.txt
#
# /kaggle/working/output_model/distilbert-imdb/checkpoint-1563:
# config.json	   optimizer.pt   scheduler.pt	      training_args.bin
# model.safetensors  rng_state.pth  trainer_state.json

# %%
# !zip -r /kaggle/working/model_output.zip /kaggle/working/output_model > /dev/null
