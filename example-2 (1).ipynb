# %%
# !pip install pytest --quiet

# %%
# !rm -rf MLops2025
# !git clone -b mlops-tasks https://github.com/nastyasova/MLops2025.git
# %cd MLops2025
# Out:
# Cloning into 'MLops2025'...
# remote: Enumerating objects: 159, done.
# remote: Counting objects: 100% (159/159), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 159 (delta 80), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (159/159), 63.16 KiB | 2.63 MiB/s, done.
# Resolving deltas: 100% (80/80), done.
# /kaggle/working/MLops2025/MLops2025/MLops2025/MLops2025

# %%
# !pip install torch==2.2.1 transformers==4.41.2 datasets==4.4.0 scikit-learn==1.4.2 pyyaml==6.0.3 pytest==8.3.2 --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 2.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 20.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.5/511.5 kB 29.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 87.3 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 23.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 5.5 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 10.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 42.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.9 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !pytest -v -s tests/test_data_pipeline.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.4.1, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /kaggle/working/MLops2025/MLops2025/MLops2025/MLops2025
# plugins: anyio-4.11.0, typeguard-4.4.4, langsmith-0.4.8
# collected 5 items
#
# tests/test_data_pipeline.py::test_dataset_not_empty PASSED
# tests/test_data_pipeline.py::test_dataset_fields_exist PASSED
# tests/test_data_pipeline.py::test_label_values_in_range PASSED
# tests/test_data_pipeline.py::test_tokenizer_output_type PASSED
# tests/test_data_pipeline.py::test_input_id_range PASSED
#
# ============================== 5 passed in 4.13s ===============================

# %%
# !ls -R
# Out:
# .:
# configs			  LICENSE  README.md	     src		tests
# example-working_t2.ipynb  models   requirements.txt  test_data_load.py
#
# ./configs:
# train_config.yaml
#
# ./models:
#
# ./src:
# data.py  evaluate.py  __init__.py  model.py  train.py  utils.py
#
# ./tests:
# __init__.py  test_basic.py  test_data_pipeline.py  test_training_pipeline.py

# %%
# !pytest -v -s tests/test_training_pipeline.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.4.1, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /kaggle/working/MLops2025/MLops2025/MLops2025/MLops2025
# plugins: anyio-4.11.0, typeguard-4.4.4, langsmith-0.4.8
# collecting ... 2025-11-06 00:29:31.171247: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762388971.194079     340 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762388971.201059     340 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !pip install -U "transformers==4.45.2" "peft==0.12.0" "accelerate==0.33.0" --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 75.7 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 25.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.1/315.1 kB 24.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 38.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 75.0 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 85.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 24.6 MB/s eta 0:00:0000:0100:01m
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 11.7 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00:00:0100:01
# ...
